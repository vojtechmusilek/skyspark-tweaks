# %%
import matplotlib.pyplot as plt
import numpy as np

x1 = np.array([598.703125, 597.703125])
y1 = np.array([295, 277])

x2 = np.array([604.3125, 591.109375])
y2 = np.array([293, 279])

plt.plot(x1, y1)
plt.plot(x2, y2)
plt.show()
